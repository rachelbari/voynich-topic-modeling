# %% [markdown]
# <h1 align="center"> Multiple Correspondence Analysis (MCA) for Data Visualization </h1>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import prince
# %matplotlib inline

# %% [markdown]
# ## Load Dataset

# %%
url = "https://raw.githubusercontent.com/rachelbari/voynich-topic-modeling/master/out/nmf_4_map.csv"

# %%
# loading dataset into Pandas DataFrame
df = pd.read_csv(url, index_col=0)
df = df.drop(['quire'], axis=1)
df
# Out:
#       folio               topic  hand language  topic_nmf
# 0       f1r           botanical     1        a          1
# 1       f1v           botanical     1        a          1
# 2       f2r           botanical     1        a          1
# 3       f2v           botanical     1        a          1
# 4       f3r           botanical     1        a          1
# 5       f3v           botanical     1        a          1
# 6       f4r           botanical     1        a          1
# 7       f4v           botanical     1        a          1
# 8       f5r           botanical     1        a          1
# 9       f5v           botanical     1        a          1
# 10      f6r           botanical     1        a          1
# 11      f6v           botanical     1        a          1
# 12      f7r           botanical     1        a          1
# 13      f7v           botanical     1        a          1
# 14      f8r           botanical     1        a          1
# 15      f8v           botanical     1        a          1
# 16      f9r           botanical     1        a          1
# 17      f9v           botanical     1        a          1
# 18     f10r           botanical     1        a          1
# 19     f10v           botanical     1        a          1
# 20     f11r           botanical     1        a          1
# 21     f11v           botanical     1        a          1
# 22     f13r           botanical     1        a          1
# 23     f13v           botanical     1        a          1
# 24     f14r           botanical     1        a          1
# 25     f14v           botanical     1        a          1
# 26     f15r           botanical     1        a          1
# 27     f15v           botanical     1        a          1
# 28     f16r           botanical     1        a          1
# 29     f16v           botanical     1        a          1
# ..      ...                 ...   ...      ...        ...
# 195   f100v            recipies     1        a          3
# 196  f101r1            recipies     1        a          3
# 197  f101v2            recipies     1        a          3
# 198  f102r1            recipies     1        a          3
# 199  f102r2            recipies     1        a          3
# 200  f102v2            recipies     1        a          3
# 201  f102v1            recipies     1        a          3
# 202   f103r  starred paragraphs     3        b          0
# 203   f103v  starred paragraphs     3        b          0
# 204   f104r  starred paragraphs     3        b          2
# 205   f104v  starred paragraphs     3        b          2
# 206   f105r  starred paragraphs     3        b          2
# 207   f105v  starred paragraphs     3        b          2
# 208   f106r  starred paragraphs     3        b          2
# 209   f106v  starred paragraphs     3        b          2
# 210   f107r  starred paragraphs     3        b          2
# 211   f107v  starred paragraphs     3        b          2
# 212   f108r  starred paragraphs     3        b          0
# 213   f108v  starred paragraphs     3        b          0
# 214   f111r  starred paragraphs     3        b          0
# 215   f111v  starred paragraphs     3        b          0
# 216   f112r  starred paragraphs     3        b          2
# 217   f112v  starred paragraphs     3        b          2
# 218   f113r  starred paragraphs     3        b          2
# 219   f113v  starred paragraphs     3        b          2
# 220   f114r  starred paragraphs     3        b          2
# 221   f114v  starred paragraphs     3        b          2
# 222   f115r  starred paragraphs     3        b          2
# 223   f115v  starred paragraphs     3        b          0
# 224   f116r  starred paragraphs     3        b          0
#
# [224 rows x 5 columns]

# %%
df.set_index('folio', inplace=True)

# %%
df.columns = ['topic', 'hand', 'language', 'nmftopic']

# %%
df
# Out:
#                      topic  hand language  nmftopic
# folio
# f1r              botanical     1        a         1
# f1v              botanical     1        a         1
# f2r              botanical     1        a         1
# f2v              botanical     1        a         1
# f3r              botanical     1        a         1
# f3v              botanical     1        a         1
# f4r              botanical     1        a         1
# f4v              botanical     1        a         1
# f5r              botanical     1        a         1
# f5v              botanical     1        a         1
# f6r              botanical     1        a         1
# f6v              botanical     1        a         1
# f7r              botanical     1        a         1
# f7v              botanical     1        a         1
# f8r              botanical     1        a         1
# f8v              botanical     1        a         1
# f9r              botanical     1        a         1
# f9v              botanical     1        a         1
# f10r             botanical     1        a         1
# f10v             botanical     1        a         1
# f11r             botanical     1        a         1
# f11v             botanical     1        a         1
# f13r             botanical     1        a         1
# f13v             botanical     1        a         1
# f14r             botanical     1        a         1
# f14v             botanical     1        a         1
# f15r             botanical     1        a         1
# f15v             botanical     1        a         1
# f16r             botanical     1        a         1
# f16v             botanical     1        a         1
# ...                    ...   ...      ...       ...
# f100v             recipies     1        a         3
# f101r1            recipies     1        a         3
# f101v2            recipies     1        a         3
# f102r1            recipies     1        a         3
# f102r2            recipies     1        a         3
# f102v2            recipies     1        a         3
# f102v1            recipies     1        a         3
# f103r   starred paragraphs     3        b         0
# f103v   starred paragraphs     3        b         0
# f104r   starred paragraphs     3        b         2
# f104v   starred paragraphs     3        b         2
# f105r   starred paragraphs     3        b         2
# f105v   starred paragraphs     3        b         2
# f106r   starred paragraphs     3        b         2
# f106v   starred paragraphs     3        b         2
# f107r   starred paragraphs     3        b         2
# f107v   starred paragraphs     3        b         2
# f108r   starred paragraphs     3        b         0
# f108v   starred paragraphs     3        b         0
# f111r   starred paragraphs     3        b         0
# f111v   starred paragraphs     3        b         0
# f112r   starred paragraphs     3        b         2
# f112v   starred paragraphs     3        b         2
# f113r   starred paragraphs     3        b         2
# f113v   starred paragraphs     3        b         2
# f114r   starred paragraphs     3        b         2
# f114v   starred paragraphs     3        b         2
# f115r   starred paragraphs     3        b         2
# f115v   starred paragraphs     3        b         0
# f116r   starred paragraphs     3        b         0
#
# [224 rows x 4 columns]

# %%
mca = prince.MCA(n_components=2, n_iter=4, copy=True, check_input=True, engine='auto', random_state=42)
mca = mca.fit(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-6f2c9ef6a4bb> in <module>()
# ----> 1 mca = prince.MCA(n_components=2, n_iter=4, copy=True, check_input=True, engine='auto', random_state=42)
#       2 mca = mca.fit(df)
#
# TypeError: __init__() got an unexpected keyword argument 'engine'

# %%
ax = mca.plot_coordinates(X=df, ax=None, figsize=(12, 12), show_row_points=True, row_points_size=10, show_row_labels=False,
                          show_column_points=True, column_points_size=30, show_column_labels=True, legend_n_cols=2)
#ax.get_figure()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3ad542eff58b> in <module>()
# ----> 1 ax = mca.plot_coordinates(X=df, ax=None, figsize=(12, 12), show_row_points=True, row_points_size=10, show_row_labels=False,
#       2                           show_column_points=True, column_points_size=30, show_column_labels=True, legend_n_cols=2)
#       3 #ax.get_figure()
#
# NameError: name 'mca' is not defined

# %% [markdown]
# We took out *Folio 57v* because it was labeled with an unknown language, topic and hand.
